# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers  #모듈(변수나 함수를 포함)만 불러오기

# BMI 데이터를 읽어 들이고 정규화하기
csv = pd.read_csv("bmi.csv")

# 몸무게와 키 데이터
csv["weight"] /= 100   #normalization
csv["height"] /= 200   #normalization
X = csv[["weight", "height"]].as_matrix()

# 레이블
bclass = {"thin":[1,0,0], "normal":[0,1,0], "fat":[0,0,1]}
y = np.empty((20000,3))     # 2000x3 크기의 다차원 벡터 생성
for i, v in enumerate(csv["label"]):
    y[i] = bclass[v]        #"thin'이면, y[i]=[1,0,0] 와 같이 할당
    
# 훈련 전용 데이터와 테스트 전용 데이터로 나누기 --- (※2)
X_train, y_train = X[1:15001], y[1:15001]
X_test,  y_test  = X[15001:20001], y[15001:20001]

print(X_train)
# Out:
# [[0.73  0.71 ]
#  [0.61  0.885]
#  [0.48  0.935]
#  ...
#  [0.8   0.865]
#  [0.38  0.955]
#  [0.55  0.69 ]]
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if sys.path[0] == '':

# %%
# 모델 구조 정의하기

model = tf.keras.Sequential()  #순차적 계층화 준비

model.add(layers.Dense(8, input_shape=(2,)))  #입력 2개로부터 전달받는 8개 노드의 layer 생성
model.add(layers.Activation('relu'))  #ReLU 활성화함수 채택
model.add(layers.Dropout(0.1))        #dropout ratio=10% (배치 훈련시 10% arc 무시)

model.add(layers.Dense(4))         #4개 노드의 layer 생성
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.1))

model.add(layers.Dense(3))
model.add(layers.Activation('softmax')) #분류(classification)을 위해 softmax 함수 사용

# 모델 구축하기
model.compile(
    loss="categorical_crossentropy",  #다중 교차엔트로피
    optimizer="rmsprop",   #최적화 기법 중 하나
    metrics=['accuracy'])  #정확도 측정

# %%
# 데이터 훈련하기 --- (※5)
hist = model.fit(
    X_train, y_train,
    batch_size=100,  #100개에 한 번씩 업데이터 실행
    epochs=50,       #훈련 데이터셋을 총 50회 반복 실험. 단, 조기중지될 수 있음
    validation_split=0.2,  
      #validation data 분할 비율. 즉, 15000개 중에서 20%인 3000개를 validation용으로 분할 (데이터에 잘학습되었는지 확인)
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)],  
      #'val_loss'를 monitor하여 감소하면 한 번 더(1) 참고 조기중지
    verbose=1)  #전 과정을 화면에 출력(1) 또는 미출력(0) 모드

# 테스트 데이터로 평가하기 --- (※6)
score = model.evaluate(X_test, y_test)
print('test_loss: ', score[0])
print('test_acc: ', score[1])
# Out:
# Train on 12000 samples, validate on 3000 samples
# Epoch 1/50
# 12000/12000 [==============================] - 3s 218us/sample - loss: 1.0951 - accuracy: 0.4227 - val_loss: 1.0873 - val_accuracy: 0.3640
# Epoch 2/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 1.0821 - accuracy: 0.5052 - val_loss: 1.0700 - val_accuracy: 0.5343
# Epoch 3/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 1.0611 - accuracy: 0.5818 - val_loss: 1.0422 - val_accuracy: 0.6797
# Epoch 4/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 1.0276 - accuracy: 0.5978 - val_loss: 1.0013 - val_accuracy: 0.6847
# Epoch 5/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.9846 - accuracy: 0.6025 - val_loss: 0.9472 - val_accuracy: 0.6843
# Epoch 6/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.9337 - accuracy: 0.6062 - val_loss: 0.8812 - val_accuracy: 0.6840
# Epoch 7/50
# 12000/12000 [==============================] - 0s 17us/sample - loss: 0.8677 - accuracy: 0.6199 - val_loss: 0.8058 - val_accuracy: 0.7173
# Epoch 8/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.8103 - accuracy: 0.6282 - val_loss: 0.7342 - val_accuracy: 0.8120
# Epoch 9/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.7504 - accuracy: 0.6557 - val_loss: 0.6633 - val_accuracy: 0.8463
# Epoch 10/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.6931 - accuracy: 0.6982 - val_loss: 0.6020 - val_accuracy: 0.8667
# Epoch 11/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.6463 - accuracy: 0.7272 - val_loss: 0.5449 - val_accuracy: 0.8837
# Epoch 12/50
# 12000/12000 [==============================] - 0s 18us/sample - loss: 0.6019 - accuracy: 0.7420 - val_loss: 0.4978 - val_accuracy: 0.9070
# Epoch 13/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.5729 - accuracy: 0.7568 - val_loss: 0.4546 - val_accuracy: 0.9203
# Epoch 14/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.5335 - accuracy: 0.7765 - val_loss: 0.4146 - val_accuracy: 0.9323
# Epoch 15/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.5133 - accuracy: 0.7814 - val_loss: 0.3826 - val_accuracy: 0.9410
# Epoch 16/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4758 - accuracy: 0.8027 - val_loss: 0.3488 - val_accuracy: 0.9470
# Epoch 17/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4569 - accuracy: 0.8064 - val_loss: 0.3241 - val_accuracy: 0.9567
# Epoch 18/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4325 - accuracy: 0.8188 - val_loss: 0.2985 - val_accuracy: 0.9607
# Epoch 19/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4178 - accuracy: 0.8248 - val_loss: 0.2804 - val_accuracy: 0.9507
# Epoch 20/50
# 12000/12000 [==============================] - 0s 17us/sample - loss: 0.4047 - accuracy: 0.8254 - val_loss: 0.2603 - val_accuracy: 0.9570
# Epoch 21/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3882 - accuracy: 0.8383 - val_loss: 0.2436 - val_accuracy: 0.9690
# Epoch 22/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3719 - accuracy: 0.8423 - val_loss: 0.2278 - val_accuracy: 0.9753
# Epoch 23/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3539 - accuracy: 0.8517 - val_loss: 0.2126 - val_accuracy: 0.9757
# Epoch 24/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3465 - accuracy: 0.8528 - val_loss: 0.2020 - val_accuracy: 0.9777
# Epoch 25/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3381 - accuracy: 0.8543 - val_loss: 0.1938 - val_accuracy: 0.9807
# Epoch 26/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3308 - accuracy: 0.8597 - val_loss: 0.1829 - val_accuracy: 0.9793
# Epoch 27/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3249 - accuracy: 0.8588 - val_loss: 0.1781 - val_accuracy: 0.9810
# Epoch 28/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3106 - accuracy: 0.8675 - val_loss: 0.1680 - val_accuracy: 0.9800
# Epoch 29/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3079 - accuracy: 0.8659 - val_loss: 0.1624 - val_accuracy: 0.9823
# Epoch 30/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.2999 - accuracy: 0.8720 - val_loss: 0.1557 - val_accuracy: 0.9770
# Epoch 31/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.2928 - accuracy: 0.8735 - val_loss: 0.1516 - val_accuracy: 0.9823
# Epoch 32/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2958 - accuracy: 0.8723 - val_loss: 0.1474 - val_accuracy: 0.9850
# Epoch 33/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2830 - accuracy: 0.8772 - val_loss: 0.1413 - val_accuracy: 0.9843
# Epoch 34/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2727 - accuracy: 0.8831 - val_loss: 0.1355 - val_accuracy: 0.9847
# Epoch 35/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.2707 - accuracy: 0.8826 - val_loss: 0.1333 - val_accuracy: 0.9823
# Epoch 36/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.2655 - accuracy: 0.8844 - val_loss: 0.1304 - val_accuracy: 0.9850
# Epoch 37/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2629 - accuracy: 0.8857 - val_loss: 0.1273 - val_accuracy: 0.9747
# Epoch 38/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2576 - accuracy: 0.8873 - val_loss: 0.1221 - val_accuracy: 0.9840
# Epoch 39/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2494 - accuracy: 0.8916 - val_loss: 0.1180 - val_accuracy: 0.9847
# Epoch 40/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.2547 - accuracy: 0.8868 - val_loss: 0.1163 - val_accuracy: 0.9810
# Epoch 41/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2513 - accuracy: 0.8877 - val_loss: 0.1170 - val_accuracy: 0.9783
# Epoch 42/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2455 - accuracy: 0.8906 - val_loss: 0.1134 - val_accuracy: 0.9800
# Epoch 43/50
# 12000/12000 [==============================] - 0s 17us/sample - loss: 0.2364 - accuracy: 0.8947 - val_loss: 0.1108 - val_accuracy: 0.9813
# Epoch 44/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2364 - accuracy: 0.8948 - val_loss: 0.1059 - val_accuracy: 0.9847
# Epoch 45/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.2369 - accuracy: 0.8926 - val_loss: 0.1044 - val_accuracy: 0.9850
# Epoch 46/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2315 - accuracy: 0.8965 - val_loss: 0.1029 - val_accuracy: 0.9827
# Epoch 47/50
# 12000/12000 [==============================] - 0s 16us/sample - loss: 0.2302 - accuracy: 0.8970 - val_loss: 0.1002 - val_accuracy: 0.9847
# Epoch 48/50
# 12000/12000 [==============================] - 0s 16us/sample - loss: 0.2280 - accuracy: 0.8996 - val_loss: 0.0975 - val_accuracy: 0.9850
# Epoch 49/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2241 - accuracy: 0.9022 - val_loss: 0.0972 - val_accuracy: 0.9843
# Epoch 50/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.2217 - accuracy: 0.9021 - val_loss: 0.0960 - val_accuracy: 0.9797
# 4999/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# test_loss:  0.09911518378671728
# test_acc:  0.98079616

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
