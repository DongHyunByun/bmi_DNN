# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers  #모듈(변수나 함수를 포함)만 불러오기

# BMI 데이터를 읽어 들이고 정규화하기
csv = pd.read_csv("bmi.csv")

# 몸무게와 키 데이터
csv["weight"] /= 100   #normalization
csv["height"] /= 200   #normalization
X = csv[["weight", "height"]].as_matrix()

# 레이블
bclass = {"thin":[1,0,0], "normal":[0,1,0], "fat":[0,0,1]}
y = np.empty((20000,3))     # 2000x3 크기의 다차원 벡터 생성
for i, v in enumerate(csv["label"]):
    y[i] = bclass[v]        #"thin'이면, y[i]=[1,0,0] 와 같이 할당
    
# 훈련 전용 데이터와 테스트 전용 데이터로 나누기 --- (※2)
X_train, y_train = X[1:15001], y[1:15001]
X_test,  y_test  = X[15001:20001], y[15001:20001]

print(X_train)
# Out:
# [[0.73  0.71 ]
#  [0.61  0.885]
#  [0.48  0.935]
#  ...
#  [0.8   0.865]
#  [0.38  0.955]
#  [0.55  0.69 ]]
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if sys.path[0] == '':

# %%
# 모델 구조 정의하기
model = tf.keras.Sequential()  #순차적 계층화 준비
model.add(layers.Dense(8, input_shape=(2,)))  #입력 2개로부터 전달받는 8개 노드의 layer 생성
model.add(layers.Activation('relu'))  #ReLU 활성화함수 채택
model.add(layers.Dropout(0.1))        #dropout ratio=10% (배치 훈련시 10% arc 무시)

model.add(layers.Dense(4))         #4개 노드의 layer 생성
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.1))

model.add(layers.Dense(3))
model.add(layers.Activation('softmax')) #분류(classification)을 위해 softmax 함수 사용

# 모델 구축하기
model.compile(
    loss="categorical_crossentropy",  #다중 교차엔트로피
    optimizer="rmsprop",   #최적화 기법 중 하나
    metrics=['accuracy'])  #정확도 측정

# %%
# 데이터 훈련하기 --- (※5)
hist = model.fit(
    X_train, y_train,
    batch_size=100,  #100개에 한 번씩 업데이터 실행
    epochs=50,       #훈련 데이터셋을 총 50회 반복 실험. 단, 조기중지될 수 있음
    validation_split=0.2,  
      #validation data 분할 비율. 즉, 15000개 중에서 20%인 3000개를 validation용으로 분할 (데이터에 잘학습되었는지 확인)
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)],  
      #'val_loss'를 monitor하여 감소하면 한 번 더(1) 참고 조기중지
    verbose=1)  #전 과정을 화면에 출력(1) 또는 미출력(0) 모드

# 테스트 데이터로 평가하기 --- (※6)
score = model.evaluate(X_test, y_test)
print('test_loss: ', score[0])
print('test_acc: ', score[1])
# Out:
# Train on 12000 samples, validate on 3000 samples
# Epoch 1/50
# 12000/12000 [==============================] - 1s 89us/sample - loss: 1.0928 - accuracy: 0.3465 - val_loss: 1.0402 - val_accuracy: 0.6733
# Epoch 2/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 1.0231 - accuracy: 0.5843 - val_loss: 0.9963 - val_accuracy: 0.6607
# Epoch 3/50
# 12000/12000 [==============================] - 0s 16us/sample - loss: 0.9814 - accuracy: 0.5951 - val_loss: 0.9476 - val_accuracy: 0.6780
# Epoch 4/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.9345 - accuracy: 0.6120 - val_loss: 0.8947 - val_accuracy: 0.6813
# Epoch 5/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.8894 - accuracy: 0.6221 - val_loss: 0.8393 - val_accuracy: 0.6833
# Epoch 6/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.8400 - accuracy: 0.6315 - val_loss: 0.7830 - val_accuracy: 0.6977
# Epoch 7/50
# 12000/12000 [==============================] - 0s 17us/sample - loss: 0.7899 - accuracy: 0.6466 - val_loss: 0.7189 - val_accuracy: 0.7370
# Epoch 8/50
# 12000/12000 [==============================] - 0s 19us/sample - loss: 0.7420 - accuracy: 0.6686 - val_loss: 0.6607 - val_accuracy: 0.7897
# Epoch 9/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.6989 - accuracy: 0.6986 - val_loss: 0.6054 - val_accuracy: 0.8343
# Epoch 10/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.6557 - accuracy: 0.7317 - val_loss: 0.5527 - val_accuracy: 0.8637
# Epoch 11/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.6163 - accuracy: 0.7549 - val_loss: 0.5077 - val_accuracy: 0.9040
# Epoch 12/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.5863 - accuracy: 0.7763 - val_loss: 0.4678 - val_accuracy: 0.9223
# Epoch 13/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.5534 - accuracy: 0.7937 - val_loss: 0.4313 - val_accuracy: 0.9233
# Epoch 14/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.5179 - accuracy: 0.8097 - val_loss: 0.4060 - val_accuracy: 0.9510
# Epoch 15/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.5022 - accuracy: 0.8107 - val_loss: 0.3772 - val_accuracy: 0.9570
# Epoch 16/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4903 - accuracy: 0.8159 - val_loss: 0.3556 - val_accuracy: 0.9597
# Epoch 17/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4617 - accuracy: 0.8281 - val_loss: 0.3325 - val_accuracy: 0.9603
# Epoch 18/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.4530 - accuracy: 0.8273 - val_loss: 0.3193 - val_accuracy: 0.9657
# Epoch 19/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4497 - accuracy: 0.8220 - val_loss: 0.3021 - val_accuracy: 0.9650
# Epoch 20/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4327 - accuracy: 0.8307 - val_loss: 0.2895 - val_accuracy: 0.9660
# Epoch 21/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4235 - accuracy: 0.8307 - val_loss: 0.2807 - val_accuracy: 0.9670
# Epoch 22/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4227 - accuracy: 0.8341 - val_loss: 0.2707 - val_accuracy: 0.9670
# Epoch 23/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4057 - accuracy: 0.8378 - val_loss: 0.2587 - val_accuracy: 0.9653
# Epoch 24/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4082 - accuracy: 0.8403 - val_loss: 0.2573 - val_accuracy: 0.9670
# Epoch 25/50
# 12000/12000 [==============================] - 0s 19us/sample - loss: 0.3946 - accuracy: 0.8494 - val_loss: 0.2482 - val_accuracy: 0.9700
# Epoch 26/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3918 - accuracy: 0.8464 - val_loss: 0.2391 - val_accuracy: 0.9660
# Epoch 27/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3924 - accuracy: 0.8474 - val_loss: 0.2355 - val_accuracy: 0.9693
# Epoch 28/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3921 - accuracy: 0.8500 - val_loss: 0.2317 - val_accuracy: 0.9720
# Epoch 29/50
# 12000/12000 [==============================] - 0s 20us/sample - loss: 0.3865 - accuracy: 0.8474 - val_loss: 0.2304 - val_accuracy: 0.9690
# Epoch 30/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3832 - accuracy: 0.8553 - val_loss: 0.2214 - val_accuracy: 0.9723
# Epoch 31/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3663 - accuracy: 0.8614 - val_loss: 0.2138 - val_accuracy: 0.9787
# Epoch 32/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3668 - accuracy: 0.8603 - val_loss: 0.2091 - val_accuracy: 0.9807
# Epoch 33/50
# 12000/12000 [==============================] - 0s 17us/sample - loss: 0.3638 - accuracy: 0.8639 - val_loss: 0.2072 - val_accuracy: 0.9807
# Epoch 34/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3711 - accuracy: 0.8601 - val_loss: 0.2039 - val_accuracy: 0.9817
# Epoch 35/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3653 - accuracy: 0.8602 - val_loss: 0.2002 - val_accuracy: 0.9870
# Epoch 36/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3664 - accuracy: 0.8615 - val_loss: 0.1961 - val_accuracy: 0.9863
# Epoch 37/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3655 - accuracy: 0.8635 - val_loss: 0.1959 - val_accuracy: 0.9867
# Epoch 38/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3534 - accuracy: 0.8677 - val_loss: 0.1942 - val_accuracy: 0.9773
# Epoch 39/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3559 - accuracy: 0.8632 - val_loss: 0.1895 - val_accuracy: 0.9867
# Epoch 40/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3565 - accuracy: 0.8651 - val_loss: 0.1890 - val_accuracy: 0.9837
# Epoch 41/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3450 - accuracy: 0.8760 - val_loss: 0.1842 - val_accuracy: 0.9883
# Epoch 42/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3475 - accuracy: 0.8713 - val_loss: 0.1814 - val_accuracy: 0.9877
# Epoch 43/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3470 - accuracy: 0.8711 - val_loss: 0.1817 - val_accuracy: 0.9860
# Epoch 44/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3463 - accuracy: 0.8727 - val_loss: 0.1805 - val_accuracy: 0.9820
# Epoch 45/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3470 - accuracy: 0.8723 - val_loss: 0.1780 - val_accuracy: 0.9893
# Epoch 46/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3442 - accuracy: 0.8722 - val_loss: 0.1773 - val_accuracy: 0.9857
# Epoch 47/50
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3403 - accuracy: 0.8756 - val_loss: 0.1762 - val_accuracy: 0.9890
# Epoch 48/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3339 - accuracy: 0.8733 - val_loss: 0.1738 - val_accuracy: 0.9870
# Epoch 49/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3323 - accuracy: 0.8748 - val_loss: 0.1717 - val_accuracy: 0.9873
# Epoch 50/50
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3379 - accuracy: 0.8711 - val_loss: 0.1701 - val_accuracy: 0.9883
# 4999/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# test_loss:  0.1715417982137401
# test_acc:  0.9837968

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()


acc_ax = loss_ax.twinx()


loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()
