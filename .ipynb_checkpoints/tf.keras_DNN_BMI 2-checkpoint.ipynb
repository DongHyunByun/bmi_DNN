# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers  #모듈(변수나 함수를 포함)만 불러오기

# BMI 데이터를 읽어 들이고 정규화하기
csv = pd.read_csv("bmi.csv")

# 몸무게와 키 데이터
csv["weight"] /= 100   #normalization
csv["height"] /= 200   #normalization
X = csv[["weight", "height"]].as_matrix()
print(csv)
# 레이블
bclass = {"thin":[1,0,0], "normal":[0,1,0], "fat":[0,0,1]}
y = np.empty((20000,3))     # 2000x3 크기의 다차원 벡터 생성
for i, v in enumerate(csv["label"]):
    y[i] = bclass[v]        #"thin'이면, y[i]=[1,0,0] 와 같이 할당
    
# 훈련 전용 데이터와 테스트 전용 데이터로 나누기 --- (※2)
X_train, y_train = X[0:15000], y[0:15000]
X_test,  y_test  = X[15000:20000], y[15000:20000]
# Out:
#        height  weight   label
# 0       0.710    0.62     fat
# 1       0.710    0.73     fat
# 2       0.885    0.61  normal
# 3       0.935    0.48    thin
# 4       0.765    0.60     fat
# ...       ...     ...     ...
# 19995   0.610    0.58     fat
# 19996   0.965    0.69  normal
# 19997   0.965    0.37    thin
# 19998   0.975    0.51    thin
# 19999   0.815    0.67  normal
#
# [20000 rows x 3 columns]
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if sys.path[0] == '':

# %%
# 모델 구조 정의하기
model = tf.keras.Sequential()  #순차적 계층화 준비
model.add(layers.Dense(8, input_shape=(2,)))  #입력 2개로부터 전달받는 8개 노드의 layer 생성
model.add(layers.Activation('relu'))  #ReLU 활성화함수 채택
model.add(layers.Dropout(0.1))        #dropout ratio=10% (배치 훈련시 10% arc 무시)

model.add(layers.Dense(4))         #4개 노드의 layer 생성
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.1))

model.add(layers.Dense(3))
model.add(layers.Activation('softmax')) #분류(classification)을 위해 softmax 함수 사용

# 모델 구축하기
model.compile(
    loss='categorical_crossentropy',  #다중 교차엔트로피
    optimizer="rmsprop",   #최적화 기법 중 하나
    metrics=['accuracy'])  #정확도 측정

# %%
# 데이터 훈련하기
hist = model.fit(
    X_train, y_train,
    batch_size=100,  #100개에 한 번씩 업데이터 실행
    epochs=30,       #훈련 데이터셋을 총 20회 반복 실험. 단, 조기중지될 수 있음
    validation_split=0.2,  
      #validation data 분할 비율. 즉, 15000개 중에서 10%인 1500개를 validation용으로 분할
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)],  
      #'val_loss'를 monitor하여 감소하면 한 번 더(1) 참고 조기중지
    verbose=1)  #전 과정을 화면에 출력(1) 또는 미출력(0) 모드

# 테스트 데이터로 평가하기
score = model.evaluate(X_test, y_test)
print('test_loss: ', score[0])
print('test_acc: ', score[1])
# Out:
# Train on 12000 samples, validate on 3000 samples
# Epoch 1/30
# 12000/12000 [==============================] - 1s 89us/sample - loss: 1.1108 - accuracy: 0.3908 - val_loss: 1.1036 - val_accuracy: 0.3637
# Epoch 2/30
# 12000/12000 [==============================] - 0s 20us/sample - loss: 1.0972 - accuracy: 0.3898 - val_loss: 1.0828 - val_accuracy: 0.3867
# Epoch 3/30
# 12000/12000 [==============================] - 0s 16us/sample - loss: 1.0669 - accuracy: 0.5865 - val_loss: 1.0501 - val_accuracy: 0.6847
# Epoch 4/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 1.0346 - accuracy: 0.6433 - val_loss: 1.0078 - val_accuracy: 0.6620
# Epoch 5/30
# 12000/12000 [==============================] - 0s 16us/sample - loss: 0.9879 - accuracy: 0.6260 - val_loss: 0.9505 - val_accuracy: 0.6760
# Epoch 6/30
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.9325 - accuracy: 0.6461 - val_loss: 0.8847 - val_accuracy: 0.7260
# Epoch 7/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.8740 - accuracy: 0.6667 - val_loss: 0.8189 - val_accuracy: 0.7600
# Epoch 8/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.8195 - accuracy: 0.6808 - val_loss: 0.7597 - val_accuracy: 0.8207
# Epoch 9/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.7690 - accuracy: 0.7006 - val_loss: 0.6971 - val_accuracy: 0.8400
# Epoch 10/30
# 12000/12000 [==============================] - 0s 16us/sample - loss: 0.7152 - accuracy: 0.7186 - val_loss: 0.6320 - val_accuracy: 0.8577
# Epoch 11/30
# 12000/12000 [==============================] - 0s 22us/sample - loss: 0.6678 - accuracy: 0.7316 - val_loss: 0.5742 - val_accuracy: 0.8753
# Epoch 12/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.6247 - accuracy: 0.7464 - val_loss: 0.5196 - val_accuracy: 0.8990
# Epoch 13/30
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.5739 - accuracy: 0.7685 - val_loss: 0.4687 - val_accuracy: 0.9147
# Epoch 14/30
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.5390 - accuracy: 0.7753 - val_loss: 0.4250 - val_accuracy: 0.9317
# Epoch 15/30
# 12000/12000 [==============================] - 0s 20us/sample - loss: 0.5056 - accuracy: 0.7915 - val_loss: 0.3878 - val_accuracy: 0.9333
# Epoch 16/30
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.4788 - accuracy: 0.7997 - val_loss: 0.3540 - val_accuracy: 0.9370
# Epoch 17/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.4520 - accuracy: 0.8094 - val_loss: 0.3255 - val_accuracy: 0.9650
# Epoch 18/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.4240 - accuracy: 0.8172 - val_loss: 0.2973 - val_accuracy: 0.9653
# Epoch 19/30
# 12000/12000 [==============================] - 0s 16us/sample - loss: 0.4100 - accuracy: 0.8201 - val_loss: 0.2767 - val_accuracy: 0.9710
# Epoch 20/30
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3967 - accuracy: 0.8257 - val_loss: 0.2597 - val_accuracy: 0.9550
# Epoch 21/30
# 12000/12000 [==============================] - 0s 16us/sample - loss: 0.3808 - accuracy: 0.8336 - val_loss: 0.2409 - val_accuracy: 0.9727
# Epoch 22/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3676 - accuracy: 0.8384 - val_loss: 0.2279 - val_accuracy: 0.9730
# Epoch 23/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3515 - accuracy: 0.8456 - val_loss: 0.2141 - val_accuracy: 0.9743
# Epoch 24/30
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3440 - accuracy: 0.8487 - val_loss: 0.2019 - val_accuracy: 0.9760
# Epoch 25/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3349 - accuracy: 0.8536 - val_loss: 0.1955 - val_accuracy: 0.9780
# Epoch 26/30
# 12000/12000 [==============================] - 0s 18us/sample - loss: 0.3263 - accuracy: 0.8612 - val_loss: 0.1841 - val_accuracy: 0.9743
# Epoch 27/30
# 12000/12000 [==============================] - 0s 14us/sample - loss: 0.3174 - accuracy: 0.8611 - val_loss: 0.1777 - val_accuracy: 0.9737
# Epoch 28/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3187 - accuracy: 0.8601 - val_loss: 0.1701 - val_accuracy: 0.9763
# Epoch 29/30
# 12000/12000 [==============================] - 0s 20us/sample - loss: 0.3029 - accuracy: 0.8715 - val_loss: 0.1647 - val_accuracy: 0.9803
# Epoch 30/30
# 12000/12000 [==============================] - 0s 15us/sample - loss: 0.3132 - accuracy: 0.8648 - val_loss: 0.1599 - val_accuracy: 0.9717
# 5000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# test_loss:  0.16549837584495544
# test_acc:  0.9686

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
model.save("dnn_BMI.h5")
print("Saved model to disk.")

#load and evaluate the saved model
from numpy import loadtxt
from tensorflow.python.keras.models import load_model

#load model
loaded_model = load_model("dnn_BMI.h5")
model.summary()

score = model.evaluate(X_test, y_test)
print('test_loss: ', score[0])
print('test_acc: ', score[1])
# Out:
# Saved model to disk.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 24
# _________________________________________________________________
# activation (Activation)      (None, 8)                 0
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# activation_1 (Activation)    (None, 4)                 0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 15
# _________________________________________________________________
# activation_2 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________
# 5000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# test_loss:  0.16549837584495544
# test_acc:  0.9686

# %%
model.save("dnn_bmi.h5")
print("Saved model to disk.")

#load and evaluate the saved model
from numpy import loadtxt
from tensorflow.python.keras.models import load_model

#load model
loaded_model = load_model("dnn_bmi.h5")
model.summary()

score = model.evaluate(X_test, y_test)
print('test_loss: ', score[0])
print('test_acc: ', score[1])
# Out:
# Saved model to disk.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 24
# _________________________________________________________________
# activation (Activation)      (None, 8)                 0
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# activation_1 (Activation)    (None, 4)                 0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 15
# _________________________________________________________________
# activation_2 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# _________________________________________________________________
# 5000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# test_loss:  0.16549837584495544
# test_acc:  0.9686

# %%
#X_test의 예측 클래스 확인하기
print(X_test)
y_pred = model.predict_classes(X_test)
y_pred[:15000]
# Out:
# [[0.55  0.69 ]
#  [0.36  0.76 ]
#  [0.72  0.915]
#  ...
#  [0.37  0.965]
#  [0.51  0.975]
#  [0.67  0.815]]
# array([2, 0, 1, ..., 0, 0, 2], dtype=int64)

# %%
#X_test의 클래스별 예측 확률 확인하기
y_pred_prob = model.predict_proba(X_test)
y_pred_prob
# Out:
# array([[6.10171305e-03, 5.51844835e-02, 9.38713849e-01],
#        [8.89472902e-01, 1.10502981e-01, 2.41869438e-05],
#        [1.18567236e-01, 8.56718779e-01, 2.47139055e-02],
#        ...,
#        [9.99727547e-01, 2.72401201e-04, 1.00696344e-11],
#        [9.95588541e-01, 4.41148877e-03, 7.02859415e-09],
#        [4.13211808e-02, 4.35531467e-01, 5.23147345e-01]], dtype=float32)

# %%
y_pred = model.predict_classes(X_test[0:5])
y_pred
# Out:
# array([2, 0, 1, 0, 1], dtype=int64)

# %%
X_test[0:5]
# Out:
# array([[0.55 , 0.69 ],
#        [0.36 , 0.76 ],
#        [0.72 , 0.915],
#        [0.51 , 0.99 ],
#        [0.47 , 0.745]])

# %%
y_pred = model.predict_classes(X_test[[1]])
y_pred
# Out:
# array([0], dtype=int64)

# %%
X_test[[1]]
# Out:
# array([[0.36, 0.76]])

# %%
X_test[1]
# Out:
# array([0.36, 0.76])

# %%
X_new = [175, 75]
X_new[0]/=200
X_new[1]/=100
X_new
# Out:
# [0.875, 0.75]

# %%
y_pred = model.predict_classes(np.array([X_new,]))
y_pred_prob = model.predict_proba(np.array([X_new,]))
print(y_pred, y_pred_prob)
# Out:
# [2] [[0.00213874 0.01357098 0.9842903 ]]

# %%
def predict_bmi(X_new):
    y_pred = model.predict_classes(np.array([X_new,]))
    y_pred_prob = model.predict_proba(np.array([X_new,]))
    print(y_pred, y_pred_prob)

# %%
X_mean = [X_train[:,0].mean(), X_train[:,1].mean()] #normal (1)
X_min = [X_train[:,0].min(), X_train[:,1].min()] #normal (1)
X_max = [X_train[:,0].max(), X_train[:,1].max()] #normal (1)
X_min_max = [X_train[:,0].min(), X_train[:,1].max()]  #thin (0)
X_max_min = [X_train[:,0].max(), X_train[:,1].min()]  #fat (2)
print("X_mean : ", X_mean)
print("X_min : ", X_min)
print("X_max : ", X_max)
print("X_min_max : ", X_min_max)
print("X_max_min : ", X_max_min)
# Out:
# X_mean :  [0.5757626666666668, 0.7999703333333333]
# X_min :  [0.35, 0.6]
# X_max :  [0.8, 1.0]
# X_min_max :  [0.35, 1.0]
# X_max_min :  [0.8, 0.6]

# %%
predict_bmi(X_mean)
predict_bmi(X_min)
predict_bmi(X_max)
predict_bmi(X_min_max)
predict_bmi(X_max_min)
# Out:
# [1] [[0.10179064 0.85294    0.04526936]]
# [1] [[0.05426934 0.59651995 0.3492107 ]]
# [1] [[0.15502988 0.8376637  0.00730651]]
# [0] [[9.9994075e-01 5.9252488e-05 2.5911448e-13]]
# [2] [[0.00143006 0.00795005 0.9906199 ]]
